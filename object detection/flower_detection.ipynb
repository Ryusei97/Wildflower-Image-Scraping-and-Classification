# %% [markdown]
# Use [Mediapipe Model Maker](https://developers.google.com/mediapipe/solutions/vision/object_detector/customize) for the bounding box algorithm

# %% [markdown]
# Download the data from roboflow and edit the categories in the jason files. The format of the data set also needs to be changed.

# %%
import os
import json
import tensorflow as tf
assert tf.__version__.startswith('2')

from mediapipe_model_maker import object_detector
# Out:
# 2023-05-30 11:23:05.501812: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/ryuseikataoka/opt/anaconda3/envs/flower/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# ...

# %%
train_path = 'wildflower.v8i.coco/train'
validation_path = 'wildflower.v8i.coco/valid'

# %%
train_data = object_detector.Dataset.from_coco_folder(train_path, cache_dir="/tmp/od_data/train")
validation_data = object_detector.Dataset.from_coco_folder(validation_path, cache_dir="/tmp/od_data/validation")
print("train_data size: ", train_data.size)
print("validation_data size: ", validation_data.size)
# Out:
# INFO:tensorflow:Cache will be stored in /tmp/od_data/train with prefix filename f1eeb82320f2b740395a45bfd4889549. Cache_prefix is /tmp/od_data/train/f1eeb82320f2b740395a45bfd4889549
# INFO:tensorflow:Cache will be stored in /tmp/od_data/train with prefix filename f1eeb82320f2b740395a45bfd4889549. Cache_prefix is /tmp/od_data/train/f1eeb82320f2b740395a45bfd4889549
# 2023-05-30 11:33:35.514711: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 100
# INFO:tensorflow:On image 100
# INFO:tensorflow:On image 200
# INFO:tensorflow:On image 200
# INFO:tensorflow:On image 300
# INFO:tensorflow:On image 300
# INFO:tensorflow:On image 400
# ...

# %%
spec = object_detector.SupportedModels.MOBILENET_MULTI_AVG
hparams = object_detector.HParams(export_dir='exported_model')
options = object_detector.ObjectDetectorOptions(
    supported_model=spec,
    hparams=hparams
)

# %%
model = object_detector.ObjectDetector.create(
    train_data=train_data,
    validation_data=validation_data,
    options=options)
# Out:
# /Users/ryuseikataoka/opt/anaconda3/envs/flower/lib/python3.9/site-packages/keras/engine/functional.py:638: UserWarning: Input dict contained keys ['6'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# ...
# Model: "retina_net_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobile_net (MobileNet)      {'2': (None, 64, 64, 32)  3704416
#                              , '3': (None, 32, 32, 64
#                              ),
#                               '4': (None, 16, 16, 160
#                              ),
#                               '5': (None, 8, 8, 192),
#                               '6': (None, 1, 1, 1280)
#                              }
#
#  fpn (FPN)                   {'5': (None, 8, 8, 128),  144928
#                               '4': (None, 16, 16, 128
#                              ),
# ...

# %%
loss, coco_metrics = model.evaluate(validation_data, batch_size=4)
print(f"Validation loss: {loss}")
print(f"Validation coco metrics: {coco_metrics}")
# Out:
# 17/17 [==============================] - 2s 73ms/step - total_loss: 0.7252 - cls_loss: 0.4460 - box_loss: 0.0042 - model_loss: 0.6568
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.32s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.267
# ...

# %%
model.export_model('flower_detection.tflite')
# Out:
# Exporting a floating point model
# /Users/ryuseikataoka/opt/anaconda3/envs/flower/lib/python3.9/site-packages/keras/engine/functional.py:638: UserWarning: Input dict contained keys ['6'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# WARNING:tensorflow:Skipping full serialization of Keras layer <official.vision.modeling.retinanet_model.RetinaNetModel object at 0x1db57ed60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <official.vision.modeling.retinanet_model.RetinaNetModel object at 0x1db57ed60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.merging.add.Add object at 0x1d5a292b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.merging.add.Add object at 0x1d5a292b0>, because it is not built.
# ...
